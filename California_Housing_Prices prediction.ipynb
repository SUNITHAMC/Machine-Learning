# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data = pd.read_csv('/dataset/housing.csv')
#gives the first 5 records 
housing_data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
housing_data.shape
# Out:
# (20640, 10)

# %%
#random 5 samples
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16471    -121.25     38.13                25.0       1305.0           270.0
# 9690     -121.66     36.71                27.0       4131.0           886.0
# 19830    -119.38     36.55                31.0       2342.0           439.0
# 13995    -117.00     34.87                16.0       6862.0          1292.0
# 18216    -122.07     37.39                19.0       1465.0           342.0
#
#        population  households  median_income  median_house_value  \
# 16471       789.0       235.0         3.2993             91100.0
# 9690       2002.0       815.0         3.2929            157500.0
# 19830      1411.0       465.0         3.0170             72000.0
# 13995      3562.0      1126.0         3.6091             87200.0
# 18216       646.0       345.0         4.7120            289300.0
#
#       ocean_proximity
# 16471          INLAND
# 9690        <1H OCEAN
# 19830          INLAND
# 13995          INLAND
# ...

# %%
#drops the rows which has unavailable data(missing values)

housing_data = housing_data.dropna()

# %%
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
#plotting scatter plot

fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(housing_data['total_rooms'], housing_data['median_house_value'])

plt.xlabel('Total Rooms')
plt.ylabel('Median house value')
# Out:
# Text(0, 0.5, 'Median house value')

# %%
#plotting scatter plot

fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(housing_data['housing_median_age'], housing_data['median_house_value'])

plt.xlabel('Median Age')
plt.ylabel('Median house value')
# Out:
# Text(0, 0.5, 'Median house value')

# %%
#plotting scatter plot

fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(housing_data['median_income'], housing_data['median_house_value'])

plt.xlabel('Median Income')
plt.ylabel('Median house value')
# Out:
# Text(0, 0.5, 'Median house value')

# %%
#if two variables move in the same direction they are said to be positively co-related( 1 denotes perfect positive co-relation)
#if two variables move in the different direction they are said to be negatively co-related.
housing_data_corelation = housing_data.corr()
housing_data_corelation
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924616           -0.109357     0.045480
# latitude            -0.924616  1.000000            0.011899    -0.036667
# housing_median_age  -0.109357  0.011899            1.000000    -0.360628
# total_rooms          0.045480 -0.036667           -0.360628     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.100270 -0.108997           -0.295787     0.857281
# households           0.056513 -0.071774           -0.302768     0.918992
# median_income       -0.015550 -0.079626           -0.118278     0.197882
# median_house_value  -0.045398 -0.144638            0.106432     0.133294
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.100270    0.056513      -0.015550
# latitude                 -0.066983   -0.108997   -0.071774      -0.079626
# ...

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(8,8))

sns.heatmap(housing_data_corelation, annot=True)

# %%
#minimum least square error
#"best fit" line is the one where the sum of squares of the lengths of these dotted lines are minimum.

# %%
#to check how many of the median_house_value records are 500001
#958 records are of same upper value. Something like this could skew the training of our machine learning model. 
#so it's best to drop these records from dataset.
#working with skewed data where lots of records are skewed around the same value, there are techiniques to work around such data

housing_data.loc[housing_data['median_house_value'] == 500001].count()
# Out:
# longitude             958
# latitude              958
# housing_median_age    958
# total_rooms           958
# total_bedrooms        958
# population            958
# households            958
# median_income         958
# median_house_value    958
# ocean_proximity       958
# dtype: int64

# %%
#simply ignore/drop the skewed data
#first calculate the index positions of all of the records(inner bracket function)

housing_data = housing_data.drop(housing_data.loc[housing_data['median_house_value'] == 500001].index)

# %%
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing_data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
#convert categorical values to numeric using one-hot encoding
housing_data = pd.get_dummies(housing_data, columns = ['ocean_proximity'])

# %%
housing_data.shape
# Out:
# (19475, 14)

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 18862    -122.21     38.11                31.0       2766.0           604.0
# 7635     -118.29     33.83                24.0       4092.0           893.0
# 18782    -122.33     40.48                26.0        695.0           126.0
# 14671    -117.09     32.81                 7.0       6100.0          1185.0
# 5676     -118.29     33.71                36.0       3135.0           746.0
#
#        population  households  median_income  median_house_value  \
# 18862      1441.0       552.0         3.1768            131000.0
# 7635       2819.0       893.0         4.1378            216500.0
# 18782       319.0       124.0         3.2788            101600.0
# 14671      2710.0      1040.0         5.5673            288200.0
# 5676       1815.0       697.0         3.7596            300000.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# ...

# %%
X = housing_data.drop('median_house_value', axis=1)

Y = housing_data['median_house_value']

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split( X, Y, test_size=0.2, random_state=0 )

# %%
x_train.shape, x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
#Normalization scales all numeric features to be between 0 and 1.
#Having features in the same scale can vastly improve the performance pf ML models.
#Fit function will fit the linear model on the training data. i.e, train the linear model using our features and target values.

from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression(normalize= True).fit(x_train, y_train)
linear_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
#R-square is the measure of how well our linear model captures the underlying variation in our training data.

print("Training Score : ", linear_reg.score(x_train, y_train))
# Out:
# Training Score :  0.6116117897680196

# %%
predictors = x_train.columns

predictors
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN'],
#       dtype='object')

# %%
#The linear model would have calculated a coefficient for each input feature in your dataset.

coefficient = pd.Series(linear_reg.coef_ , predictors).sort_values()

print(coefficient)
# Out:
# ocean_proximity_INLAND       -4.158834e+17
# ocean_proximity_NEAR BAY     -4.158834e+17
# ocean_proximity_<1H OCEAN    -4.158834e+17
# ocean_proximity_NEAR OCEAN   -4.158834e+17
# ocean_proximity_ISLAND       -4.158834e+17
# longitude                    -2.427059e+04
# latitude                     -2.235330e+04
# population                   -3.046615e+01
# total_rooms                  -6.793593e+00
# households                    4.362845e+01
# total_bedrooms                8.935702e+01
# housing_median_age            9.156752e+02
# median_income                 3.846412e+04
# dtype: float64

# %%
y_pred=linear_reg.predict(x_test)

# %%
#create a dataframe to view the predicted and the actual scores.

y_pred_actual = pd.DataFrame({'predicted':y_pred, 'actual':y_test})

y_pred_actual.head(10)
# Out:
#        predicted    actual
# 19234   315712.0  313000.0
# 1859    129024.0  122400.0
# 51      151680.0   93800.0
# 11192   174528.0  198800.0
# 20355   152640.0  162500.0
# 13937   137984.0  117600.0
# 7965    184320.0  155400.0
# 9446     85312.0  104200.0
# 11377   272320.0  260900.0
# 10365   204224.0  236200.0

# %%
#The R-squared on the test data is close to the train data and hence it is good model.


from sklearn.metrics import r2_score

print("Testing_score : ",r2_score(y_test, y_pred) )
# Out:
# Testing_score :  0.6181504862593683

# %%
#plotting scatter plot

fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(y_test, y_pred)

plt.show()

# %%
df_pred_actual_sample = y_pred_actual.sample(100)
df_pred_actual_sample = df_pred_actual_sample.reset_index()

# %%
df_pred_actual_sample.head()
# Out:
#    index  predicted    actual
# 0  17183   392256.0  371800.0
# 1   2669    57536.0   43300.0
# 2   4899   115712.0   93400.0
# 3  17525   241216.0  166700.0
# 4   2224   202304.0  150900.0

# %%
#plotting scatter plot
#predicted values are in blue and actual values are in orange.

fig, ax = plt.subplots(figsize=(20,10))

plt.plot(df_pred_actual_sample['predicted'], label= 'Predicted')
plt.plot(df_pred_actual_sample['actual'], label= 'Actual')

plt.ylabel('Median house value')

plt.legend()
plt.show()
